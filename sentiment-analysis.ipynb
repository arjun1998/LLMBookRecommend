# %%
import pandas as pd
books=pd.read_csv('books_with_categories.csv')

# %%
from transformers import pipeline
pipe = pipeline("text-classification", model="j-hartmann/emotion-english-distilroberta-base",top_k=None)
pipe("I love ")
# Out:
# Device set to use cuda:0
# [[{'label': 'joy', 'score': 0.8494364619255066},
#   {'label': 'sadness', 'score': 0.0757671371102333},
#   {'label': 'anger', 'score': 0.03278326615691185},
#   {'label': 'fear', 'score': 0.025493239983916283},
#   {'label': 'disgust', 'score': 0.009747621603310108},
#   {'label': 'neutral', 'score': 0.006097023840993643},
#   {'label': 'surprise', 'score': 0.0006753400666639209}]]

# %%
pipe(books["description"][0])
# Out:
# [[{'label': 'fear', 'score': 0.65484219789505},
#   {'label': 'neutral', 'score': 0.16985157132148743},
#   {'label': 'sadness', 'score': 0.11640847474336624},
#   {'label': 'surprise', 'score': 0.020700668916106224},
#   {'label': 'disgust', 'score': 0.01910071261227131},
#   {'label': 'joy', 'score': 0.015161195769906044},
#   {'label': 'anger', 'score': 0.003935148473829031}]]

# %%
pipe(books["description"][0].split("."))
# Out:
# [[{'label': 'surprise', 'score': 0.7296026349067688},
#   {'label': 'neutral', 'score': 0.14038565754890442},
#   {'label': 'fear', 'score': 0.0681622102856636},
#   {'label': 'joy', 'score': 0.047942474484443665},
#   {'label': 'anger', 'score': 0.009156355634331703},
#   {'label': 'disgust', 'score': 0.002628473797813058},
#   {'label': 'sadness', 'score': 0.002122160280123353}],
#  [{'label': 'neutral', 'score': 0.4493710994720459},
#   {'label': 'disgust', 'score': 0.27359139919281006},
#   {'label': 'joy', 'score': 0.10908272117376328},
#   {'label': 'sadness', 'score': 0.09362725168466568},
#   {'label': 'anger', 'score': 0.04047825187444687},
#   {'label': 'surprise', 'score': 0.026970187202095985},
#   {'label': 'fear', 'score': 0.006879056338220835}],
#  [{'label': 'neutral', 'score': 0.6462159156799316},
#   {'label': 'sadness', 'score': 0.24273325502872467},
#   {'label': 'disgust', 'score': 0.04342271387577057},
#   {'label': 'surprise', 'score': 0.028300529345870018},
#   {'label': 'joy', 'score': 0.014211471192538738},
#   {'label': 'fear', 'score': 0.01408412680029869},
#   {'label': 'anger', 'score': 0.011031901463866234}],
#  [{'label': 'fear', 'score': 0.9281678199768066},
#   {'label': 'anger', 'score': 0.032191094011068344},
#   {'label': 'neutral', 'score': 0.012808727100491524},
#   {'label': 'sadness', 'score': 0.008756891824305058},
#   {'label': 'surprise', 'score': 0.00859794206917286},
#   {'label': 'disgust', 'score': 0.008431855589151382},
#   {'label': 'joy', 'score': 0.0010455838637426496}],
#  [{'label': 'sadness', 'score': 0.9671575427055359},
#   {'label': 'neutral', 'score': 0.015104170888662338},
#   {'label': 'disgust', 'score': 0.006480602081865072},
#   {'label': 'fear', 'score': 0.0053939977660775185},
#   {'label': 'surprise', 'score': 0.0022869461681693792},
#   {'label': 'anger', 'score': 0.0018428928451612592},
#   {'label': 'joy', 'score': 0.0017338814213871956}],
#  [{'label': 'joy', 'score': 0.9327970147132874},
#   {'label': 'disgust', 'score': 0.03771783411502838},
#   {'label': 'neutral', 'score': 0.015891974791884422},
#   {'label': 'sadness', 'score': 0.00644455011934042},
#   {'label': 'anger', 'score': 0.005025031510740519},
#   {'label': 'surprise', 'score': 0.0015812099445611238},
#   {'label': 'fear', 'score': 0.0005423107650130987}],
#  [{'label': 'joy', 'score': 0.6528707146644592},
#   {'label': 'neutral', 'score': 0.2542746067047119},
#   {'label': 'surprise', 'score': 0.06808306276798248},
#   {'label': 'sadness', 'score': 0.00990898534655571},
#   {'label': 'disgust', 'score': 0.006512197200208902},
#   {'label': 'anger', 'score': 0.004821308422833681},
#   {'label': 'fear', 'score': 0.00352901010774076}],
#  [{'label': 'neutral', 'score': 0.5494765043258667},
#   {'label': 'sadness', 'score': 0.1116902157664299},
#   {'label': 'disgust', 'score': 0.10400670766830444},
#   {'label': 'surprise', 'score': 0.07876554876565933},
#   {'label': 'anger', 'score': 0.0641336739063263},
#   {'label': 'fear', 'score': 0.05136284604668617},
#   {'label': 'joy', 'score': 0.04056443274021149}]]

# %%
sentences=books["description"][0].split(".")
predictions=pipe(sentences)

# %%
predictions
# Out:
# [[{'label': 'surprise', 'score': 0.7296026349067688},
#   {'label': 'neutral', 'score': 0.14038565754890442},
#   {'label': 'fear', 'score': 0.0681622102856636},
#   {'label': 'joy', 'score': 0.047942474484443665},
#   {'label': 'anger', 'score': 0.009156355634331703},
#   {'label': 'disgust', 'score': 0.002628473797813058},
#   {'label': 'sadness', 'score': 0.002122160280123353}],
#  [{'label': 'neutral', 'score': 0.4493710994720459},
#   {'label': 'disgust', 'score': 0.27359139919281006},
#   {'label': 'joy', 'score': 0.10908272117376328},
#   {'label': 'sadness', 'score': 0.09362725168466568},
#   {'label': 'anger', 'score': 0.04047825187444687},
#   {'label': 'surprise', 'score': 0.026970187202095985},
#   {'label': 'fear', 'score': 0.006879056338220835}],
#  [{'label': 'neutral', 'score': 0.6462159156799316},
#   {'label': 'sadness', 'score': 0.24273325502872467},
#   {'label': 'disgust', 'score': 0.04342271387577057},
#   {'label': 'surprise', 'score': 0.028300529345870018},
#   {'label': 'joy', 'score': 0.014211471192538738},
#   {'label': 'fear', 'score': 0.01408412680029869},
#   {'label': 'anger', 'score': 0.011031901463866234}],
#  [{'label': 'fear', 'score': 0.9281678199768066},
#   {'label': 'anger', 'score': 0.032191094011068344},
#   {'label': 'neutral', 'score': 0.012808727100491524},
#   {'label': 'sadness', 'score': 0.008756891824305058},
#   {'label': 'surprise', 'score': 0.00859794206917286},
#   {'label': 'disgust', 'score': 0.008431855589151382},
#   {'label': 'joy', 'score': 0.0010455838637426496}],
#  [{'label': 'sadness', 'score': 0.9671575427055359},
#   {'label': 'neutral', 'score': 0.015104170888662338},
#   {'label': 'disgust', 'score': 0.006480602081865072},
#   {'label': 'fear', 'score': 0.0053939977660775185},
#   {'label': 'surprise', 'score': 0.0022869461681693792},
#   {'label': 'anger', 'score': 0.0018428928451612592},
#   {'label': 'joy', 'score': 0.0017338814213871956}],
#  [{'label': 'joy', 'score': 0.9327970147132874},
#   {'label': 'disgust', 'score': 0.03771783411502838},
#   {'label': 'neutral', 'score': 0.015891974791884422},
#   {'label': 'sadness', 'score': 0.00644455011934042},
#   {'label': 'anger', 'score': 0.005025031510740519},
#   {'label': 'surprise', 'score': 0.0015812099445611238},
#   {'label': 'fear', 'score': 0.0005423107650130987}],
#  [{'label': 'joy', 'score': 0.6528707146644592},
#   {'label': 'neutral', 'score': 0.2542746067047119},
#   {'label': 'surprise', 'score': 0.06808306276798248},
#   {'label': 'sadness', 'score': 0.00990898534655571},
#   {'label': 'disgust', 'score': 0.006512197200208902},
#   {'label': 'anger', 'score': 0.004821308422833681},
#   {'label': 'fear', 'score': 0.00352901010774076}],
#  [{'label': 'neutral', 'score': 0.5494765043258667},
#   {'label': 'sadness', 'score': 0.1116902157664299},
#   {'label': 'disgust', 'score': 0.10400670766830444},
#   {'label': 'surprise', 'score': 0.07876554876565933},
#   {'label': 'anger', 'score': 0.0641336739063263},
#   {'label': 'fear', 'score': 0.05136284604668617},
#   {'label': 'joy', 'score': 0.04056443274021149}]]

# %%
sorted(predictions[0],key=lambda x:x["label"])
# Out:
# [{'label': 'anger', 'score': 0.009156355634331703},
#  {'label': 'disgust', 'score': 0.002628473797813058},
#  {'label': 'fear', 'score': 0.0681622102856636},
#  {'label': 'joy', 'score': 0.047942474484443665},
#  {'label': 'neutral', 'score': 0.14038565754890442},
#  {'label': 'sadness', 'score': 0.002122160280123353},
#  {'label': 'surprise', 'score': 0.7296026349067688}]

# %%
import numpy as np
emotion_labels=["anger","disgust","fear","joy","sadness","surprise","neutral"]
isbn=[]
emotion_scores={label:[] for label in emotion_labels}

# %%
def max_emotion_score(predictions):
    per_emotion_scores={label:[] for label in emotion_labels}
    for prediction in predictions:
        sorted_prediction=sorted(prediction,key=lambda x:x["label"])
        for index,label in enumerate(emotion_labels):
            per_emotion_scores[label].append(sorted_prediction[index]["score"])
    return {label:np.max(scores) for label,scores in per_emotion_scores.items()}

# %%
for i in range(10):
    isbn.append(books["isbn13"][i])
    sentences=books["description"][i].split(".")
    predictions=pipe(sentences)
    max_scores = max_emotion_score(predictions)
    for label in emotion_labels:
        emotion_scores[label].append(max_scores[label])
# Out:
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset

# %%
# Out:
# {'anger': [0.0641336739063263,
#   0.6126190423965454,
#   0.0641336739063263,
#   0.35148337483406067,
#   0.08141230791807175,
#   0.23222438991069794,
#   0.5381830930709839,
#   0.0641336739063263,
#   0.3006700873374939,
#   0.0641336739063263],
#  'disgust': [0.27359139919281006,
#   0.3482845425605774,
#   0.10400670766830444,
#   0.15072230994701385,
#   0.18449527025222778,
#   0.7271752953529358,
#   0.15585480630397797,
#   0.10400670766830444,
#   0.2794809937477112,
#   0.17792755365371704],
#  'fear': [0.9281678199768066,
#   0.9425276517868042,
#   0.9723208546638489,
#   0.36070728302001953,
#   0.09504339098930359,
#   0.05136284604668617,
#   0.7474285960197449,
#   0.404495507478714,
#   0.9155241250991821,
#   0.05136284604668617],
#  'joy': [0.9327970147132874,
#   0.7044207453727722,
#   0.7672367691993713,
#   0.2518812119960785,
#   0.04056443274021149,
#   0.04337586835026741,
#   0.8725652694702148,
#   0.04056443274021149,
#   0.04056443274021149,
#   0.04056443274021149],
#  'sadness': [0.6462159156799316,
#   0.8879395127296448,
#   0.5494765043258667,
#   0.732685387134552,
#   0.8843894600868225,
#   0.6213921308517456,
#   0.7121942639350891,
#   0.5494765043258667,
#   0.8402896523475647,
#   0.8603722453117371],
#  'surprise': [0.9671575427055359,
#   0.1116902157664299,
#   0.1116902157664299,
#   0.1116902157664299,
#   0.47588053345680237,
#   0.1116902157664299,
#   0.40799960494041443,
#   0.8202828764915466,
#   0.35445958375930786,
#   0.1116902157664299],
#  'neutral': [0.7296026349067688,
#   0.25254490971565247,
#   0.07876554876565933,
#   0.07876554876565933,
#   0.07876554876565933,
#   0.27190327644348145,
#   0.07876554876565933,
#   0.23448754847049713,
#   0.1356138437986374,
#   0.07876554876565933]}

# %%
from tqdm import tqdm
emotion_labels=["anger","disgust","fear","joy","sadness","surprise","neutral"]
isbn=[]
emotion_scores={label:[] for label in emotion_labels}

for i in tqdm(range(len(books))):
    isbn.append(books["isbn13"][i])
    sentences=books["description"][i].split(".")
    predictions=pipe(sentences)
    max_scores = max_emotion_score(predictions)
    for label in emotion_labels:
        emotion_scores[label].append(max_scores[label])
# Out:
# 100%|██████████| 5197/5197 [01:49<00:00, 47.43it/s]

# %%
emotions_df=pd.DataFrame(emotion_scores)
emotions_df['isbn13']=isbn

# %%
emotions_df
# Out:
#          anger   disgust      fear       joy   sadness  surprise   neutral  \
# 0     0.064134  0.273591  0.928168  0.932797  0.646216  0.967158  0.729603
# 1     0.612619  0.348285  0.942528  0.704421  0.887940  0.111690  0.252545
# 2     0.064134  0.104007  0.972321  0.767237  0.549477  0.111690  0.078766
# 3     0.351483  0.150722  0.360707  0.251881  0.732685  0.111690  0.078766
# 4     0.081412  0.184495  0.095043  0.040564  0.884389  0.475881  0.078766
# ...        ...       ...       ...       ...       ...       ...       ...
# 5192  0.148208  0.030643  0.919165  0.255170  0.853722  0.980877  0.030656
# 5193  0.064134  0.114383  0.051363  0.400263  0.883199  0.111690  0.227765
# 5194  0.009997  0.009929  0.339218  0.947779  0.375755  0.066685  0.057625
# 5195  0.064134  0.104007  0.459269  0.759456  0.951104  0.368112  0.078766
# 5196  0.064134  0.104007  0.051363  0.958549  0.915193  0.111690  0.078766
#
#              isbn13
# 0     9780002005883
# 1     9780002261982
# 2     9780006178736
# 3     9780006280897
# 4     9780006280934
# ...             ...
# 5192  9788172235222
# 5193  9788173031014
# 5194  9788179921623
# 5195  9788185300535
# 5196  9789027712059
#
# [5197 rows x 8 columns]

# %%
books=pd.merge(books,emotions_df,on="isbn13")

# %%
books
# Out:
#              isbn13      isbn10  \
# 0     9780002005883  0002005883
# 1     9780002261982  0002261987
# 2     9780006178736  0006178731
# 3     9780006280897  0006280897
# 4     9780006280934  0006280935
# ...             ...         ...
# 5192  9788172235222  8172235224
# 5193  9788173031014  8173031010
# 5194  9788179921623  817992162X
# 5195  9788185300535  8185300534
# 5196  9789027712059  9027712050
#
#                                                   title  \
# 0                                                Gilead
# 1                                          Spider's Web
# 2                                        Rage of angels
# 3                                        The Four Loves
# 4                                   The Problem of Pain
# ...                                                 ...
# 5192                                  Mistaken Identity
# 5193                                Journey to the East
# 5194  The Monk Who Sold His Ferrari: A Fable About F...
# 5195                                          I Am that
# 5196                           The Berlin Phenomenology
#
#                                            authors  \
# 0                               Marilynne Robinson
# 1                  Charles Osborne;Agatha Christie
# 2                                   Sidney Sheldon
# 3                              Clive Staples Lewis
# 4                              Clive Staples Lewis
# ...                                            ...
# 5192                              Nayantara Sahgal
# 5193                                 Hermann Hesse
# 5194                                  Robin Sharma
# 5195  Sri Nisargadatta Maharaj;Sudhakar S. Dikshit
# 5196                 Georg Wilhelm Friedrich Hegel
#
#                          categories  \
# 0                           Fiction
# 1     Detective and mystery stories
# 2                           Fiction
# 3                    Christian life
# 4                    Christian life
# ...                             ...
# 5192        Indic fiction (English)
# 5193              Adventure stories
# 5194               Health & Fitness
# 5195                     Philosophy
# 5196                        History
#
#                                               thumbnail  \
# 0     http://books.google.com/books/content?id=KQZCP...
# 1     http://books.google.com/books/content?id=gA5GP...
# 2     http://books.google.com/books/content?id=FKo2T...
# 3     http://books.google.com/books/content?id=XhQ5X...
# 4     http://books.google.com/books/content?id=Kk-uV...
# ...                                                 ...
# 5192  http://books.google.com/books/content?id=q-tKP...
# 5193  http://books.google.com/books/content?id=rq6JP...
# 5194  http://books.google.com/books/content?id=c_7mf...
# 5195  http://books.google.com/books/content?id=Fv_JP...
# 5196  http://books.google.com/books/content?id=Vy7Sk...
#
#                                             description  published_year  \
# 0     A NOVEL THAT READERS and critics have been eag...          2004.0
# 1     A new 'Christie for Christmas' -- a full-lengt...          2000.0
# 2     A memorable, mesmerizing heroine Jennifer -- b...          1993.0
# 3     Lewis' work on the nature of love divides love...          2002.0
# 4     "In The Problem of Pain, C.S. Lewis, one of th...          2002.0
# ...                                                 ...             ...
# 5192  On A Train Journey Home To North India After L...          2003.0
# 5193  This book tells the tale of a man who goes on ...          2002.0
# 5194  Wisdom to Create a Life of Passion, Purpose, a...          2003.0
# 5195  This collection of the timeless teachings of o...          1999.0
# 5196  Since the three volume edition ofHegel's Philo...          1981.0
#
#       average_rating  num_pages  ...  \
# 0               3.85      247.0  ...
# 1               3.83      241.0  ...
# 2               3.93      512.0  ...
# 3               4.15      170.0  ...
# 4               4.09      176.0  ...
# ...              ...        ...  ...
# 5192            2.93      324.0  ...
# 5193            3.70      175.0  ...
# 5194            3.82      198.0  ...
# 5195            4.51      531.0  ...
# 5196            0.00      210.0  ...
#
#                                      title_and_subtitle  \
# 0                                                Gilead
# 1                                 Spider's Web: A Novel
# 2                                        Rage of angels
# 3                                        The Four Loves
# 4                                   The Problem of Pain
# ...                                                 ...
# 5192                                  Mistaken Identity
# 5193                                Journey to the East
# 5194  The Monk Who Sold His Ferrari: A Fable About F...
# 5195     I Am that: Talks with Sri Nisargadatta Maharaj
# 5196                           The Berlin Phenomenology
#
#                                      tagged description simple_categories  \
# 0     9780002005883 A NOVEL THAT READERS and critics...           Fiction
# 1     9780002261982 A new 'Christie for Christmas' -...           Fiction
# 2     9780006178736 A memorable, mesmerizing heroine...           Fiction
# 3     9780006280897 Lewis' work on the nature of lov...        Nonfiction
# 4     9780006280934 "In The Problem of Pain, C.S. Le...        Nonfiction
# ...                                                 ...               ...
# 5192  9788172235222 On A Train Journey Home To North...           Fiction
# 5193  9788173031014 This book tells the tale of a ma...        Nonfiction
# 5194  9788179921623 Wisdom to Create a Life of Passi...           Fiction
# 5195  9788185300535 This collection of the timeless ...        Nonfiction
# 5196  9789027712059 Since the three volume edition o...        Nonfiction
#
#          anger   disgust      fear       joy   sadness  surprise   neutral
# 0     0.064134  0.273591  0.928168  0.932797  0.646216  0.967158  0.729603
# 1     0.612619  0.348285  0.942528  0.704421  0.887940  0.111690  0.252545
# 2     0.064134  0.104007  0.972321  0.767237  0.549477  0.111690  0.078766
# 3     0.351483  0.150722  0.360707  0.251881  0.732685  0.111690  0.078766
# 4     0.081412  0.184495  0.095043  0.040564  0.884389  0.475881  0.078766
# ...        ...       ...       ...       ...       ...       ...       ...
# 5192  0.148208  0.030643  0.919165  0.255170  0.853722  0.980877  0.030656
# 5193  0.064134  0.114383  0.051363  0.400263  0.883199  0.111690  0.227765
# 5194  0.009997  0.009929  0.339218  0.947779  0.375755  0.066685  0.057625
# 5195  0.064134  0.104007  0.459269  0.759456  0.951104  0.368112  0.078766
# 5196  0.064134  0.104007  0.051363  0.958549  0.915193  0.111690  0.078766
#
# [5197 rows x 21 columns]

# %%
books.to_csv('books_with_emotions.csv',index=False)
